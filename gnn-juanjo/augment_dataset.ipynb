# %% [markdown]
# # Augment Datasets

# %%
# Requirement...
# pip install spherogram pandas json

# %%
import augment_tools

# %%
# Parameters
dataset_path = "datasets/knotinfoWithGraph.csv"

# %% [markdown]
# ## Augment Links Dataset

# %%
augment_tools.augmentData(5, dataset_path, "knotInfo_augmented.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 augment_tools.augmentData(5, dataset_path, "knotInfo_augmented.csv")
#
# File c:\Users\juanj\OneDrive\Documentos\GitHub\geometricDeepLearningKnotData\gnn-juanjo\augment_tools.py:50, in augmentData(shuffledKnots, originPath, savePath)
#      48 for _ in range(shuffledKnots):
#      49     knotinfo_augmented = knotinfo.copy()
# ---> 50     knotinfo_augmented["PD Notation"] = knotinfo_augmented["knot"].apply(augmentKnot).apply(formatPD_Notation)
#      51     # knotinfo_augmented["knot"]
#      52     augmented_dataframes.append(knotinfo_augmented)
#
# File c:\Users\juanj\OneDrive\Documentos\GitHub\geometricDeepLearningKnotData\gnn-juanjo\.venv\Lib\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
# ...
