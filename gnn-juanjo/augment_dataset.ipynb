# %% [markdown]
# # Augment Datasets

# %%
# Requirement...
# pip install spherogram pandas json

# %%
import augment_tools

# %%
# Parameters
dataset_path = "datasets/knotinfoWithGraph.csv"

# %% [markdown]
# ## Augment Links Dataset

# %%
augment_tools.augmentData(30, dataset_path, "knotInfo_augmented_30.csv")
