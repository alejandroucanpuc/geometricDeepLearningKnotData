# %%
# pip install snappy plink

# %%
import spherogram
import json
import plink
from snappy import *

# %%
pd_code = "[[6;1;7;2];[10;7;5;8];[4;5;1;6];[2;10;3;9];[8;4;9;3]]"
pd_code = "[[33; 0; 34; 1]; [49; 33; 40; 32]; [9; 41; 10; 40]; [41; 16; 42; 17]; [17; 11; 18; 10]; [43; 15; 44; 14]; [15; 45; 0; 44]; [47; 12; 48; 13]; [18; 31; 19; 32]; [19; 25; 20; 24]; [8; 16; 9; 39]; [1; 34; 2; 35]; [23; 31; 24; 30]; [11; 48; 12; 49]; [29; 21; 30; 20]; [28; 26; 29; 25]; [27; 22; 28; 23]; [35; 2; 36; 3]; [4; 8; 5; 7]; [37; 7; 38; 6]; [21; 26; 22; 27]; [3; 36; 4; 37]; [5; 39; 6; 38]; [13; 46; 14; 47]; [42; 45; 43; 46]]"

# %%
a = spherogram.Link(json.loads(pd_code.replace(";",",")))
a.view()
# %gui tk

# %%
a.exterior().volume()
# Out:
# 7.3277247534
